# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Meta/blob/master/tutorials/1-Introduction/FinRL_PortfolioAllocation_NeurIPS_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

matplotlib.use('Agg')
# @formatter:off
# %matplotlib inline
# @formatter:on
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline, convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
# sys.path.append("../FinRL-Library")

from stable_baselines3.a2c import A2C

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os

if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date='2008-01-01',
                      end_date='2021-10-31',
                      ticker_list=config_tickers.DOW_30_TICKER, time_interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (101615, 9)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-01-02   7.116786   7.152143   6.876786   6.958571   5.931610
# 1  2008-01-02  46.599998  47.040001  46.259998  46.599998  34.931576
# 2  2008-01-02  52.090000  52.320000  50.790001  51.040001  40.034740
# 3  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481621
# 4  2008-01-02  72.559998  72.669998  70.050003  70.629997  46.318192
#
#        volume   tic  day
# 0  1079178800  AAPL    2
# 1     7934400  AMGN    2
# 2     8053700   AXP    2
# 3     4303000    BA    2
# 4     6337800   CAT    2

# %%
df.shape
# Out:
# (101615, 9)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
    use_technical_indicator=True,
    use_turbulence=False,
    user_defined_feature=False)

df = fe.preprocess_data(df)
# Out:
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# ...
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators

# %%
df.shape
# Out:
# (97524, 17)

# %%
df.head()
# Out:
#              date       open       high        low      close      adjcp  \
# 0      2008-01-02   7.116786   7.152143   6.876786   6.958571   5.931610
# 3483   2008-01-02  46.599998  47.040001  46.259998  46.599998  34.931576
# 6966   2008-01-02  52.090000  52.320000  50.790001  51.040001  40.034740
# 10449  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481621
# 13932  2008-01-02  72.559998  72.669998  70.050003  70.629997  46.318192
#
#            volume   tic  day  macd   boll_ub   boll_lb  rsi_30     cci_30  \
# 0      1079178800  AAPL    2   0.0  6.964725  6.955632   100.0 -66.666667
# 3483      7934400  AMGN    2   0.0  6.964725  6.955632   100.0 -66.666667
# 6966      8053700   AXP    2   0.0  6.964725  6.955632   100.0 -66.666667
# 10449     4303000    BA    2   0.0  6.964725  6.955632   100.0 -66.666667
# 13932     6337800   CAT    2   0.0  6.964725  6.955632   100.0 -66.666667
#
#        dx_30  close_30_sma  close_60_sma
# 0      100.0      6.958571      6.958571
# 3483   100.0     46.599998     46.599998
# 6966   100.0     51.040001     51.040001
# 10449  100.0     86.620003     86.620003
# 13932  100.0     70.629997     70.629997

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df = df.sort_values(['date', 'tic'], ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback = 252
for i in range(lookback, len(df.index.unique())):
    data_lookback = df.loc[i - lookback:i, :]
    price_lookback = data_lookback.pivot_table(index='date', columns='tic', values='close')
    return_lookback = price_lookback.pct_change().dropna()
    return_list.append(return_lookback)

    covs = return_lookback.cov().values
    cov_list.append(covs)

df_cov = pd.DataFrame({'date': df.date.unique()[lookback:], 'cov_list': cov_list, 'return_list': return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date', 'tic']).reset_index(drop=True)  #%% md
# Out:
#   Cell In[13], line 22
#     < a
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

matplotlib.use('Agg')
# @formatter:off
# %matplotlib inline
# @formatter:on
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline, convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
# sys.path.append("../FinRL-Library")

from stable_baselines3.a2c import A2C

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os

if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date='2008-01-01',
                      end_date='2021-10-31',
                      ticker_list=config_tickers.DOW_30_TICKER, time_interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (101615, 9)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-01-02   7.116786   7.152143   6.876786   6.958571   5.931610
# 1  2008-01-02  46.599998  47.040001  46.259998  46.599998  34.931587
# 2  2008-01-02  52.090000  52.320000  50.790001  51.040001  40.034744
# 3  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481617
# 4  2008-01-02  72.559998  72.669998  70.050003  70.629997  46.318226
#
#        volume   tic  day
# 0  1079178800  AAPL    2
# 1     7934400  AMGN    2
# 2     8053700   AXP    2
# 3     4303000    BA    2
# 4     6337800   CAT    2

# %%
df.shape
# Out:
# (101615, 9)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
    use_technical_indicator=True,
    use_turbulence=False,
    user_defined_feature=False)

df = fe.preprocess_data(df)
# Out:
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# ...
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators

# %%
df.shape
# Out:
# (97524, 17)

# %%
df.head()
# Out:
#              date       open       high        low      close      adjcp  \
# 0      2008-01-02   7.116786   7.152143   6.876786   6.958571   5.931610
# 3483   2008-01-02  46.599998  47.040001  46.259998  46.599998  34.931587
# 6966   2008-01-02  52.090000  52.320000  50.790001  51.040001  40.034744
# 10449  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481617
# 13932  2008-01-02  72.559998  72.669998  70.050003  70.629997  46.318226
#
#            volume   tic  day  macd   boll_ub   boll_lb  rsi_30     cci_30  \
# 0      1079178800  AAPL    2   0.0  6.964725  6.955632   100.0 -66.666667
# 3483      7934400  AMGN    2   0.0  6.964725  6.955632   100.0 -66.666667
# 6966      8053700   AXP    2   0.0  6.964725  6.955632   100.0 -66.666667
# 10449     4303000    BA    2   0.0  6.964725  6.955632   100.0 -66.666667
# 13932     6337800   CAT    2   0.0  6.964725  6.955632   100.0 -66.666667
#
#        dx_30  close_30_sma  close_60_sma
# 0      100.0      6.958571      6.958571
# 3483   100.0     46.599998     46.599998
# 6966   100.0     51.040001     51.040001
# 10449  100.0     86.620003     86.620003
# 13932  100.0     70.629997     70.629997

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df = df.sort_values(['date', 'tic'], ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback = 252
for i in range(lookback, len(df.index.unique())):
    data_lookback = df.loc[i - lookback:i, :]
    price_lookback = data_lookback.pivot_table(index='date', columns='tic', values='close')
    return_lookback = price_lookback.pct_change().dropna()
    return_list.append(return_lookback)

    covs = return_lookback.cov().values
    cov_list.append(covs)

df_cov = pd.DataFrame({'date': df.date.unique()[lookback:], 'cov_list': cov_list, 'return_list': return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date', 'tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (90468, 19)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-12-31   3.070357   3.133571   3.047857   3.048214   2.598352
# 1  2008-12-31  57.110001  58.220001  57.060001  57.750000  43.289665
# 2  2008-12-31  17.969999  18.750000  17.910000  18.549999  14.745291
# 3  2008-12-31  41.590000  43.049999  41.500000  42.669998  32.005886
# 4  2008-12-31  43.700001  45.099998  43.700001  44.669998  30.071383
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  607541200  AAPL    2 -0.097446   3.649552   2.895305  42.254771
# 1    6287200  AMGN    2  0.216368  58.947401  56.388599  51.060614
# 2    9625600   AXP    2 -1.191668  23.723023  16.106977  42.521170
# 3    5443100    BA    2 -0.391219  42.894634  38.486366  47.290375
# 4    6277400   CAT    2  0.979845  45.785565  38.404435  51.073052
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -80.847207  16.129793      3.243631      3.375887
# 1   51.895357  10.432018     56.671334     56.044333
# 2  -74.811722  25.776759     20.030000     22.412000
# 3  157.922391   5.366299     40.432000     43.304500
# 4   98.904653  26.331746     40.266000     39.918333
#
#                                             cov_list  \
# 0  [[0.001348968986171653, 0.00042841264280825875...
# 1  [[0.001348968986171653, 0.00042841264280825875...
# 2  [[0.001348968986171653, 0.00042841264280825875...
# 3  [[0.001348968986171653, 0.00042841264280825875...
# 4  [[0.001348968986171653, 0.00042841264280825875...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01', '2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2009-01-02   3.067143   3.251429   3.041429   3.241071   2.762747
# 0  2009-01-02  58.590000  59.080002  57.750000  58.990002  44.219177
# 0  2009-01-02  18.570000  19.520000  18.400000  19.330000  15.365305
# 0  2009-01-02  42.799999  45.560001  42.779999  45.250000  33.941101
# 0  2009-01-02  44.910000  46.980000  44.709999  46.910000  31.579329
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  746015200  AAPL    4 -0.082758   3.633600   2.892864  45.440193
# 0    6547900  AMGN    4  0.320448  59.148360  56.339640  52.756859
# 0   10955700   AXP    4 -1.059847  23.489423  16.086577  43.923322
# 0    7010200    BA    4 -0.019566  43.926849  37.932151  50.664690
# 0    7117200   CAT    4  1.248426  46.543072  38.372928  53.534743
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -30.508777   2.140064      3.244631      3.376833
# 0   94.549630   0.814217     56.759667     56.166000
# 0  -42.018825  16.335101     20.028333     22.263333
# 0  275.696308  20.494464     40.621667     43.237334
# 0  131.675975  34.637448     40.623333     39.911333
#
#                                             cov_list  \
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib

matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                 df,
                 stock_dim,
                 hmax,
                 initial_amount,
                 transaction_cost_pct,
                 reward_scaling,
                 state_space,
                 action_space,
                 tech_indicator_list,
                 turbulence_threshold=None,
                 lookback=252,
                 day=0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback = lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct = transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low=0, high=1, shape=(self.action_space,))
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                            shape=(self.state_space + len(self.tech_indicator_list), self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day, :]
        self.covs = self.data['cov_list'].values[0]
        self.state = np.append(np.array(self.covs),
                               [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory = [[1 / self.stock_dim] * self.stock_dim]
        self.date_memory = [self.data.date.unique()[0]]

    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(), 'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory, 'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() != 0:
                sharpe = (252 ** 0.5) * df_daily_return['daily_return'].mean() / \
                         df_daily_return['daily_return'].std()
                print("Sharpe: ", sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal, {}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions)
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day, :]
            self.covs = self.data['cov_list'].values[0]
            self.state = np.append(np.array(self.covs),
                                   [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values) - 1) * weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value * (1 + portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day, :]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state = np.append(np.array(self.covs),
                               [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory = [[1 / self.stock_dim] * self.stock_dim]
        self.date_memory = [self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output

    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date': date_list, 'daily_return': portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 28

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df=train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env=env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env=env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)

# %%
filepath_a2c = f"trained_models/trained_a2c.zip"
if "trained_a2c" in vars() and trained_a2c:
    trained_a2c.save(filepath_a2c)
else:
    trained_a2c = A2C.load(filepath_a2c)

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env=env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)

# %%
trained_ppo = agent.train_model(model=model_ppo,
                                tb_log_name='ppo',
                                total_timesteps=80000)

# %%
trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env=env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}

model_ddpg = agent.get_model("ddpg", model_kwargs=DDPG_PARAMS)

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                                 tb_log_name='ddpg',
                                 total_timesteps=50000)

# %%
trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env=env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac", model_kwargs=SAC_PARAMS)

# %%
trained_sac = agent.train_model(model=model_sac,
                                tb_log_name='sac',
                                total_timesteps=50000)

# %%
trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env=env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3", model_kwargs=TD3_PARAMS)

# %%
trained_td3 = agent.train_model(model=model_td3,
                                tb_log_name='td3',
                                total_timesteps=30000)

# %%
trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df, '2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df=trade, **env_kwargs)

# %%
trade.shape

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                                                      environment=e_trade_gym)

# %%
df_daily_return.head()

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries

DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats
perf_stats_all = perf_func(returns=DRL_strat,
                           factor_returns=DRL_strat,
                           positions=None, transactions=None, turnover_denom="AGB")

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
    ticker="^DJI",
    start=df_daily_return.loc[0, 'date'],
    end=df_daily_return.loc[len(df_daily_return) - 1, 'date'])

stats = backtest_stats(baseline_df, value_col_name='close')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# @formatter:off
# %matplotlib inline
# @formatter:on

baseline_df = get_baseline(
    ticker='^DJI', start=df_daily_return.loc[0, 'date'], end='2021-11-01'
)

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
    pyfolio.create_full_tear_sheet(returns=DRL_strat,
                                   benchmark_rets=baseline_returns, set_context=False)

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
% pip install PyPortfolioOpt

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index=range(1), columns=unique_trade_date)
initial_capital = 1000000
portfolio.loc[0, unique_trade_date[0]] = initial_capital

for i in range(len(unique_trade_date) - 1):
    df_temp = df[df.date == unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date == unique_trade_date[i + 1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma, weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                          / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value
    portfolio.iloc[0, i + 1] = np.dot(current_shares, next_price)

portfolio = portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()

# %%
a2c_cumpod = (df_daily_return.daily_return + 1).cumprod() - 1

# %%
min_var_cumpod = (portfolio.account_value.pct_change() + 1).cumprod() - 1

# %%
dji_cumpod = (baseline_returns + 1).cumprod() - 1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
% pip install plotly

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x=time_ind, y=a2c_cumpod, mode='lines', name='A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x=time_ind, y=dji_cumpod, mode='lines', name='DJIA')
trace2_portfolio = go.Scatter(x=time_ind, y=min_var_cumpod, mode='lines', name='Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)

fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
    #'text': "Cumulative Return using FinRL",
    'y': 0.85,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
    #    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
    xaxis={'type': 'date',
           'tick0': time_ind[0],
           'tickmode': 'linear',
           'dtick': 86400000.0 * 80}

)
fig.update_xaxes(showline=True, linecolor='black', showgrid=True, gridwidth=1, gridcolor='LightSteelBlue', mirror=True)
fig.update_yaxes(showline=True, linecolor='black', showgrid=True, gridwidth=1, gridcolor='LightSteelBlue', mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()

# %%
df.shape

# %%
df.head()

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01', '2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.head()

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib

matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then 
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step
        

    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                 df,
                 stock_dim,
                 hmax,
                 initial_amount,
                 transaction_cost_pct,
                 reward_scaling,
                 state_space,
                 action_space,
                 tech_indicator_list,
                 turbulence_threshold=None,
                 lookback=252,
                 day=0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback = lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct = transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low=0, high=1, shape=(self.action_space,))
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                            shape=(self.state_space + len(self.tech_indicator_list), self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day, :]
        self.covs = self.data['cov_list'].values[0]
        self.state = np.append(np.array(self.covs),
                               [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory = [[1 / self.stock_dim] * self.stock_dim]
        self.date_memory = [self.data.date.unique()[0]]

    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(), 'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory, 'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() != 0:
                sharpe = (252 ** 0.5) * df_daily_return['daily_return'].mean() / \
                         df_daily_return['daily_return'].std()
                print("Sharpe: ", sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal, {}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions)
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day, :]
            self.covs = self.data['cov_list'].values[0]
            self.state = np.append(np.array(self.covs),
                                   [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values) - 1) * weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value * (1 + portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day, :]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state = np.append(np.array(self.covs),
                               [self.data[tech].values.tolist() for tech in self.tech_indicator_list], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory = [[1 / self.stock_dim] * self.stock_dim]
        self.date_memory = [self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output

    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date': date_list, 'daily_return': portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df=train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env=env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env=env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -39.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.67e+08  |
# |    reward             | 1520943.6 |
# |    std                | 0.998     |
# |    value_loss         | 2.44e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 426       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.24e+08  |
# |    reward             | 1839496.4 |
# |    std                | 0.997     |
# |    value_loss         | 3.59e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 435       |
# |    iterations         | 300       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.8e+08   |
# |    reward             | 2625978.0 |
# |    std                | 0.996     |
# |    value_loss         | 7.7e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 439       |
# |    iterations         | 400       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 3054206.8 |
# |    std                | 0.996     |
# |    value_loss         | 9.34e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 4.86e+08  |
# |    reward             | 3979482.0 |
# |    std                | 0.995     |
# |    value_loss         | 1.77e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4388960.447939463
# Sharpe:  0.7999217665163088
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 600       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.12e+08  |
# |    reward             | 1082031.6 |
# |    std                | 0.995     |
# |    value_loss         | 1.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 421       |
# |    iterations         | 700       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.96e+08  |
# |    reward             | 1638580.4 |
# |    std                | 0.994     |
# |    value_loss         | 2.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 424       |
# |    iterations         | 800       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 2.73e+08  |
# |    reward             | 2201996.2 |
# |    std                | 0.994     |
# |    value_loss         | 5.2e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 423       |
# |    iterations         | 900       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 2913941.0 |
# |    std                | 0.994     |
# |    value_loss         | 8.94e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 1000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 4e+08     |
# |    reward             | 3318961.0 |
# |    std                | 0.994     |
# |    value_loss         | 1.22e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 1100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 5.53e+08  |
# |    reward             | 4477945.5 |
# |    std                | 0.994     |
# |    value_loss         | 2.25e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4438319.529766744
# Sharpe:  0.8042588867646755
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 1200      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.38e+08  |
# |    reward             | 1275290.1 |
# |    std                | 0.994     |
# |    value_loss         | 1.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 1300      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 1.81e+08  |
# |    reward             | 1511281.5 |
# |    std                | 0.994     |
# |    value_loss         | 2.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 403       |
# |    iterations         | 1400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.74e+08  |
# |    reward             | 2254010.0 |
# |    std                | 0.993     |
# |    value_loss         | 5.26e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 1500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.29e+08  |
# |    reward             | 2774791.0 |
# |    std                | 0.993     |
# |    value_loss         | 7.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 1600      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 3.85e+08  |
# |    reward             | 3559903.8 |
# |    std                | 0.992     |
# |    value_loss         | 1.32e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 1700      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 4.8e+08   |
# |    reward             | 4534723.5 |
# |    std                | 0.991     |
# |    value_loss         | 2.09e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4549402.049677727
# Sharpe:  0.813823630958675
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 1800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.7e+08   |
# |    reward             | 1476021.1 |
# |    std                | 0.991     |
# |    value_loss         | 2.22e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 1900      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.16e+08  |
# |    reward             | 1877663.6 |
# |    std                | 0.99      |
# |    value_loss         | 3.81e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 2000      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 2.68e+08  |
# |    reward             | 2586319.5 |
# |    std                | 0.99      |
# |    value_loss         | 6.89e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 2100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.38e+08  |
# |    reward             | 3006210.0 |
# |    std                | 0.989     |
# |    value_loss         | 9.53e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 2200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 4.44e+08  |
# |    reward             | 3911441.2 |
# |    std                | 0.989     |
# |    value_loss         | 1.83e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 2300      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 4.97e+08  |
# |    reward             | 3700919.0 |
# |    std                | 0.989     |
# |    value_loss         | 1.91e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4556675.598858105
# Sharpe:  0.8149589392079091
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 2400      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.58e+08  |
# |    reward             | 1343871.0 |
# |    std                | 0.989     |
# |    value_loss         | 1.81e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 2500      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 2.16e+08  |
# |    reward             | 1776195.2 |
# |    std                | 0.989     |
# |    value_loss         | 3.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 2600      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 3.1e+08   |
# |    reward             | 2611759.0 |
# |    std                | 0.988     |
# |    value_loss         | 7.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 2700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 3.17e+08  |
# |    reward             | 2877184.8 |
# |    std                | 0.988     |
# |    value_loss         | 8.93e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 2800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 4.4e+08   |
# |    reward             | 3952571.2 |
# |    std                | 0.988     |
# |    value_loss         | 1.62e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4139257.1718353415
# Sharpe:  0.76771585766774
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 2900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.12e+08  |
# |    reward             | 838428.7  |
# |    std                | 0.987     |
# |    value_loss         | 8.48e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 3000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 2.15e+08  |
# |    reward             | 1741545.1 |
# |    std                | 0.986     |
# |    value_loss         | 3.22e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 3100      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 2.41e+08  |
# |    reward             | 2244439.5 |
# |    std                | 0.986     |
# |    value_loss         | 5.33e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 3200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 3.68e+08  |
# |    reward             | 3144123.0 |
# |    std                | 0.986     |
# |    value_loss         | 1.02e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 3300      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 4.3e+08   |
# |    reward             | 3681124.0 |
# |    std                | 0.986     |
# |    value_loss         | 1.45e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 3400      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 5.85e+08  |
# |    reward             | 4802745.0 |
# |    std                | 0.986     |
# |    value_loss         | 2.43e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5291170.825281184
# Sharpe:  0.8769732797349531
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 3500      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.24e+08  |
# |    reward             | 1141650.4 |
# |    std                | 0.985     |
# |    value_loss         | 1.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 3600      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 2.14e+08  |
# |    reward             | 1720717.9 |
# |    std                | 0.984     |
# |    value_loss         | 3.11e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 3700      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.51e+08  |
# |    reward             | 2360404.8 |
# |    std                | 0.984     |
# |    value_loss         | 5.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 3800      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 3.37e+08  |
# |    reward             | 3053836.8 |
# |    std                | 0.983     |
# |    value_loss         | 9.52e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 3900      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 4.23e+08  |
# |    reward             | 3667471.2 |
# |    std                | 0.983     |
# |    value_loss         | 1.42e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 418       |
# |    iterations         | 4000      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 5.29e+08  |
# |    reward             | 4949810.0 |
# |    std                | 0.982     |
# |    value_loss         | 2.52e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4878920.312410544
# Sharpe:  0.8313586347727571
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4100      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 1.56e+08  |
# |    reward             | 1358663.0 |
# |    std                | 0.982     |
# |    value_loss         | 1.89e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4200      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.92e+08  |
# |    reward             | 1613967.2 |
# |    std                | 0.981     |
# |    value_loss         | 2.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4300      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 2.91e+08  |
# |    reward             | 2471342.0 |
# |    std                | 0.981     |
# |    value_loss         | 6.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4400      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 3.39e+08  |
# |    reward             | 2861253.0 |
# |    std                | 0.981     |
# |    value_loss         | 9.09e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 4.5e+08   |
# |    reward             | 3882240.5 |
# |    std                | 0.98      |
# |    value_loss         | 1.58e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 417       |
# |    iterations         | 4600      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 6.17e+08  |
# |    reward             | 4838634.5 |
# |    std                | 0.981     |
# |    value_loss         | 2.55e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4597147.157613909
# Sharpe:  0.8099170383139802
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 4700      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.56e+08  |
# |    reward             | 1383699.6 |
# |    std                | 0.98      |
# |    value_loss         | 1.9e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 4800      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1782203.2 |
# |    std                | 0.98      |
# |    value_loss         | 3.38e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 4900      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 2.99e+08  |
# |    reward             | 2698679.5 |
# |    std                | 0.979     |
# |    value_loss         | 7.64e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5000      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 3.3e+08   |
# |    reward             | 3010510.2 |
# |    std                | 0.979     |
# |    value_loss         | 9.92e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5100      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 4.78e+08  |
# |    reward             | 4437118.0 |
# |    std                | 0.978     |
# |    value_loss         | 1.99e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 416       |
# |    iterations         | 5200      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 5.15e+08  |
# |    reward             | 4792351.0 |
# |    std                | 0.978     |
# |    value_loss         | 2.44e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5051508.445424395
# Sharpe:  0.8558112871823591
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 5300      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.7e+08   |
# |    reward             | 1483522.9 |
# |    std                | 0.978     |
# |    value_loss         | 2.29e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5400      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.21e+08  |
# |    reward             | 1893742.9 |
# |    std                | 0.978     |
# |    value_loss         | 4.04e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5500      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 2.8e+08   |
# |    reward             | 2757477.0 |
# |    std                | 0.978     |
# |    value_loss         | 7.34e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5600      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 3.73e+08  |
# |    reward             | 3154602.0 |
# |    std                | 0.978     |
# |    value_loss         | 1.07e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 415       |
# |    iterations         | 5700      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 5.5e+08   |
# |    reward             | 4532000.5 |
# |    std                | 0.977     |
# |    value_loss         | 2.41e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5099911.0760459
# Sharpe:  0.8526986491215356
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 5800      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 1.09e+08  |
# |    reward             | 978832.25 |
# |    std                | 0.977     |
# |    value_loss         | 9.5e+12   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 5900      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.93e+08  |
# |    reward             | 1671988.1 |
# |    std                | 0.977     |
# |    value_loss         | 2.92e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 6000      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.4e+08   |
# |    reward             | 2126954.8 |
# |    std                | 0.976     |
# |    value_loss         | 4.87e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 6100      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 3.15e+08  |
# |    reward             | 2835378.0 |
# |    std                | 0.976     |
# |    value_loss         | 8.83e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 6200      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 3.83e+08  |
# |    reward             | 3345603.0 |
# |    std                | 0.975     |
# |    value_loss         | 1.22e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 6300      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 4.97e+08  |
# |    reward             | 4388184.0 |
# |    std                | 0.975     |
# |    value_loss         | 1.98e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4498329.639172283
# Sharpe:  0.7943500032749414
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6400      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.34e+08  |
# |    reward             | 1292902.4 |
# |    std                | 0.975     |
# |    value_loss         | 1.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6500      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 1.78e+08  |
# |    reward             | 1551185.5 |
# |    std                | 0.974     |
# |    value_loss         | 2.79e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6600      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.62e+08  |
# |    reward             | 2303268.2 |
# |    std                | 0.974     |
# |    value_loss         | 5.55e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6700      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 3.17e+08  |
# |    reward             | 2651501.2 |
# |    std                | 0.974     |
# |    value_loss         | 7.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6800      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 4.44e+08  |
# |    reward             | 3672066.2 |
# |    std                | 0.973     |
# |    value_loss         | 1.44e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 412       |
# |    iterations         | 6900      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 5.27e+08  |
# |    reward             | 4870102.5 |
# |    std                | 0.973     |
# |    value_loss         | 2.46e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4815281.755016684
# Sharpe:  0.8290655795960297
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 7000      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 1.32e+08  |
# |    reward             | 1315205.2 |
# |    std                | 0.972     |
# |    value_loss         | 1.72e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 7100      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.98e+08  |
# |    reward             | 1742031.8 |
# |    std                | 0.972     |
# |    value_loss         | 3.14e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 7200      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 2.57e+08  |
# |    reward             | 2335056.0 |
# |    std                | 0.971     |
# |    value_loss         | 5.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 7300      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 2.97e+08  |
# |    reward             | 2565149.2 |
# |    std                | 0.971     |
# |    value_loss         | 6.75e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 7400      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 4.68e+08  |
# |    reward             | 4003889.8 |
# |    std                | 0.971     |
# |    value_loss         | 1.7e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 7500      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7499      |
# |    policy_loss        | 5.32e+08  |
# |    reward             | 4715847.5 |
# |    std                | 0.971     |
# |    value_loss         | 2.46e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4424390.861676695
# Sharpe:  0.7985572789333376
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 7600      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 1.54e+08  |
# |    reward             | 1404388.0 |
# |    std                | 0.97      |
# |    value_loss         | 2.02e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 7700      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 1.96e+08  |
# |    reward             | 1802368.0 |
# |    std                | 0.969     |
# |    value_loss         | 3.42e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 7800      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 3.06e+08  |
# |    reward             | 2702733.0 |
# |    std                | 0.969     |
# |    value_loss         | 7.76e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 7900      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 3.51e+08  |
# |    reward             | 3052092.8 |
# |    std                | 0.967     |
# |    value_loss         | 9.21e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 8000      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 4.5e+08   |
# |    reward             | 3960056.5 |
# |    std                | 0.967     |
# |    value_loss         | 1.69e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8100      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 5.27e+08  |
# |    reward             | 4551269.0 |
# |    std                | 0.967     |
# |    value_loss         | 2.31e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4602875.983434406
# Sharpe:  0.8160021407644412
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 8200      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 1.89e+08  |
# |    reward             | 1540282.0 |
# |    std                | 0.967     |
# |    value_loss         | 2.51e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8300      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 2.09e+08  |
# |    reward             | 1860058.0 |
# |    std                | 0.967     |
# |    value_loss         | 3.64e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8400      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 3.27e+08  |
# |    reward             | 2653487.8 |
# |    std                | 0.966     |
# |    value_loss         | 8.15e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8500      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 3.61e+08  |
# |    reward             | 3165518.2 |
# |    std                | 0.966     |
# |    value_loss         | 1.03e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8600      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 4.7e+08   |
# |    reward             | 4402854.0 |
# |    std                | 0.965     |
# |    value_loss         | 1.97e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4978268.805929318
# Sharpe:  0.8425941016997663
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8700      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 1.18e+08  |
# |    reward             | 1071378.5 |
# |    std                | 0.965     |
# |    value_loss         | 1.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8800      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 1.98e+08  |
# |    reward             | 1658634.2 |
# |    std                | 0.965     |
# |    value_loss         | 2.98e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 8900      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 2.95e+08  |
# |    reward             | 2307674.2 |
# |    std                | 0.965     |
# |    value_loss         | 5.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9000      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 3.5e+08   |
# |    reward             | 2972738.0 |
# |    std                | 0.964     |
# |    value_loss         | 9.21e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9100      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 4.16e+08  |
# |    reward             | 3570193.2 |
# |    std                | 0.964     |
# |    value_loss         | 1.35e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9200      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 6.12e+08  |
# |    reward             | 4694462.0 |
# |    std                | 0.964     |
# |    value_loss         | 2.43e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4946438.441800212
# Sharpe:  0.8431615102897012
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 9300      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.26e+08  |
# |    reward             | 1236601.5 |
# |    std                | 0.964     |
# |    value_loss         | 1.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9400      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 1.85e+08  |
# |    reward             | 1599521.2 |
# |    std                | 0.964     |
# |    value_loss         | 2.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9500      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 2.5e+08   |
# |    reward             | 2274697.2 |
# |    std                | 0.964     |
# |    value_loss         | 5.38e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9600      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.19e+08  |
# |    reward             | 2659269.2 |
# |    std                | 0.963     |
# |    value_loss         | 7.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9700      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 4.07e+08  |
# |    reward             | 3545877.2 |
# |    std                | 0.963     |
# |    value_loss         | 1.32e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9800      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 4.89e+08  |
# |    reward             | 4482128.0 |
# |    std                | 0.963     |
# |    value_loss         | 2.08e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4569136.560211464
# Sharpe:  0.8066769403796542
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 9900      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.68e+08  |
# |    reward             | 1469087.4 |
# |    std                | 0.963     |
# |    value_loss         | 2.23e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 10000     |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.03e+08  |
# |    reward             | 1895991.1 |
# |    std                | 0.962     |
# |    value_loss         | 3.8e+13   |
# -------------------------------------

# %%
filepath_a2c = f"trained_models/trained_a2c.zip"
if trained_a2c'trained_a2c:
trained_a2c.save(filepath_a2c)
else:
trained_a2c = A2C.load(filepath_a2c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3     trained_a2c.save(filepath_a2c)
#       4 else:
# ----> 5     trained_a2c = A2C.load(filepath_a2c)
#
# NameError: name 'A2C' is not defined

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env=env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)

# %%
trained_ppo = agent.train_model(model=model_ppo,
                                tb_log_name='ppo',
                                total_timesteps=80000)

# %%
trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env=env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}

model_ddpg = agent.get_model("ddpg", model_kwargs=DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                                 tb_log_name='ddpg',
                                 total_timesteps=50000)

# %%
trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env=env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac", model_kwargs=SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac,
                                tb_log_name='sac',
                                total_timesteps=50000)

# %%
trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env=env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3", model_kwargs=TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3,
                                tb_log_name='td3',
                                total_timesteps=30000)

# %%
trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df, '2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df=trade, **env_kwargs)

# %%
trade.shape
# Out:
# (9436, 19)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                                                      environment=e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1400890.0876424804
# Sharpe:  1.9194729493752376
# =================================
# hit end!

# %%
df_daily_return.head()
# Out:
#          date  daily_return
# 0  2020-07-01      0.000000
# 1  2020-07-02      0.003584
# 2  2020-07-06      0.016309
# 3  2020-07-07     -0.013842
# 4  2020-07-08      0.006242

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.025319  0.028052  0.036242  0.025319  0.065355  0.045434
# 2020-07-06  0.025319  0.028052  0.036242  0.025319  0.065355  0.045434
# 2020-07-07  0.025319  0.028052  0.036242  0.025319  0.065355  0.045434
# 2020-07-08  0.025319  0.028052  0.036242  0.025319  0.065355  0.045434
#
#                 CSCO       CVX       DIS        GS  ...       MMM       MRK  \
# date                                                ...
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  ...  0.035714  0.035714
# 2020-07-02  0.068825  0.031602  0.025319  0.025319  ...  0.025319  0.025319
# 2020-07-06  0.068825  0.031602  0.025319  0.025319  ...  0.025319  0.025319
# 2020-07-07  0.068825  0.031602  0.025319  0.025319  ...  0.025319  0.025319
# 2020-07-08  0.068825  0.031602  0.025319  0.025319  ...  0.025319  0.025319
#
#                 MSFT       NKE        PG       TRV       UNH        VZ  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.068333  0.025319  0.025319  0.025319  0.025319  0.047424
# 2020-07-06  0.068333  0.025319  0.025319  0.025319  0.025319  0.047424
# 2020-07-07  0.068333  0.025319  0.025319  0.025319  0.025319  0.047424
# 2020-07-08  0.068333  0.025319  0.025319  0.025319  0.025319  0.047424
#
#                  WBA       WMT
# date
# 2020-07-01  0.035714  0.035714
# 2020-07-02  0.025319  0.025319
# 2020-07-06  0.025319  0.025319
# 2020-07-07  0.025319  0.025319
# 2020-07-08  0.025319  0.025319
#
# [5 rows x 28 columns]

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries

DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats
perf_stats_all = perf_func(returns=DRL_strat,
                           factor_returns=DRL_strat,
                           positions=None, transactions=None, turnover_denom="AGB")
# Out:
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.286700
# Cumulative returns     0.400890
# Annual volatility      0.136215
# Sharpe ratio           1.919473
# Calmar ratio           3.379738
# Stability              0.918606
# Max drawdown          -0.084829
# Omega ratio            1.379249
# Sortino ratio          2.893657
# Skew                  -0.232167
# Kurtosis               1.289413
# Tail ratio             1.099051
# Daily value at risk   -0.016124
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
    ticker="^DJI",
    start=df_daily_return.loc[0, 'date'],
    end=df_daily_return.loc[len(df_daily_return) - 1, 'date'])

stats = backtest_stats(baseline_df, value_col_name='close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# @formatter:off
# %matplotlib inline
# @formatter:on

baseline_df = get_baseline(
    ticker='^DJI', start=df_daily_return.loc[0, 'date'], end='2021-11-01'
)

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
    pyfolio.create_full_tear_sheet(returns=DRL_strat,
                                   benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/plotting.py:648: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>28.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>40.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.6%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.92</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.38</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.5%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.38</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.89</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.23</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.6%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.96</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 13
#      10 baseline_returns = get_daily_return(baseline_df, value_col_name="close")
#      12 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 13     pyfolio.create_full_tear_sheet(returns=DRL_strat,
#      14                                    benchmark_rets=baseline_returns, set_context=False)
#
# File ~/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/tears.py:201, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, style_factor_panel, sectors, caps, shares_held, volumes, percentile, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     195     returns = txn.adjust_returns_for_slippage(returns, positions,
#     196                                               transactions, slippage)
#     198 positions = utils.check_intraday(estimate_intraday, returns,
#     199                                  positions, transactions)
# --> 201 create_returns_tear_sheet(
#     202     returns,
#     203     positions=positions,
#     204     transactions=transactions,
#     205     live_start_date=live_start_date,
#     206     cone_std=cone_std,
#     207     benchmark_rets=benchmark_rets,
#     208     bootstrap=bootstrap,
#     209     turnover_denom=turnover_denom,
#     210     header_rows=header_rows,
#     211     set_context=set_context)
#     213 create_interesting_times_tear_sheet(returns,
#     214                                     benchmark_rets=benchmark_rets,
#     215                                     set_context=set_context)
#     217 if positions is not None:
#
# File ~/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/plotting.py:54, in customize.<locals>.call_w_context(*args, **kwargs)
#      52         return func(*args, **kwargs)
#      53 else:
# ---> 54     return func(*args, **kwargs)
#
# File ~/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/tears.py:504, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     494     returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     496 plotting.show_perf_stats(returns, benchmark_rets,
#     497                          positions=positions,
#     498                          transactions=transactions,
#    (...)
#     501                          live_start_date=live_start_date,
#     502                          header_rows=header_rows)
# --> 504 plotting.show_worst_drawdown_periods(returns)
#     506 vertical_sections = 11
#     508 if live_start_date is not None:
#
# File ~/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/plotting.py:1664, in show_worst_drawdown_periods(returns, top)
#    1648 def show_worst_drawdown_periods(returns, top=5):
#    1649     """
#    1650     Prints information about the worst drawdown periods.
#    1651
#    (...)
#    1661         Amount of top drawdowns periods to plot (default 5).
#    1662     """
# -> 1664     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1665     utils.print_table(
#    1666         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#    1667         name='Worst drawdown periods',
#    1668         float_format='{0:.2f}'.format,
#    1669     )
#
# File ~/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages/pyfolio/timeseries.py:1008, in gen_drawdown_table(returns, top)
#    1003     df_drawdowns.loc[i, 'Duration'] = len(pd.date_range(peak,
#    1004                                                         recovery,
#    1005                                                         freq='B'))
#    1006 df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                     .strftime('%Y-%m-%d'))
# -> 1008 df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                       .strftime('%Y-%m-%d'))
#    1010 if isinstance(recovery, float):
#    1011     df_drawdowns.loc[i, 'Recovery date'] = recovery
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %formatter:off
# %pip install PyPortfolioOpt
# %formatter:on
# Out:
# Requirement already satisfied: PyPortfolioOpt in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (1.5.4)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from PyPortfolioOpt) (1.24.1)
# Requirement already satisfied: pandas>=0.19 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from PyPortfolioOpt) (1.5.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from PyPortfolioOpt) (1.3.0)
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from PyPortfolioOpt) (1.10.0)
# Requirement already satisfied: scs>=1.1.6 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.2)
# Requirement already satisfied: setuptools<=64.0.2 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (64.0.2)
# Requirement already satisfied: osqp>=0.4.1 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.12)
# Requirement already satisfied: pytz>=2020.1 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from pandas>=0.19->PyPortfolioOpt) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: qdldl in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post3)
# Requirement already satisfied: six>=1.5 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-12-31   3.070357   3.133571   3.047857   3.048214   2.598352
# 1  2008-12-31  57.110001  58.220001  57.060001  57.750000  43.289665
# 2  2008-12-31  17.969999  18.750000  17.910000  18.549999  14.745291
# 3  2008-12-31  41.590000  43.049999  41.500000  42.669998  32.005886
# 4  2008-12-31  43.700001  45.099998  43.700001  44.669998  30.071383
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  607541200  AAPL    2 -0.097446   3.649552   2.895305  42.254771
# 1    6287200  AMGN    2  0.216368  58.947401  56.388599  51.060614
# 2    9625600   AXP    2 -1.191668  23.723023  16.106977  42.521170
# 3    5443100    BA    2 -0.391219  42.894634  38.486366  47.290375
# 4    6277400   CAT    2  0.979845  45.785565  38.404435  51.073052
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -80.847207  16.129793      3.243631      3.375887
# 1   51.895357  10.432018     56.671334     56.044333
# 2  -74.811722  25.776759     20.030000     22.412000
# 3  157.922391   5.366299     40.432000     43.304500
# 4   98.904653  26.331746     40.266000     39.918333
#
#                                             cov_list  \
# 0  [[0.001348968986171653, 0.00042841264280825875...
# 1  [[0.001348968986171653, 0.00042841264280825875...
# 2  [[0.001348968986171653, 0.00042841264280825875...
# 3  [[0.001348968986171653, 0.00042841264280825875...
# 4  [[0.001348968986171653, 0.00042841264280825875...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index=range(1), columns=unique_trade_date)
initial_capital = 1000000
portfolio.loc[0, unique_trade_date[0]] = initial_capital

for i in range(len(unique_trade_date) - 1):
    df_temp = df[df.date == unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date == unique_trade_date[i + 1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma, weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                          / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value 
    portfolio.iloc[0, i + 1] = np.dot(current_shares, next_price)

portfolio = portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1005234.883501
# 2020-07-06  1014933.780399
# 2020-07-07  1014238.666671
# 2020-07-08  1012674.038646

# %%
a2c_cumpod = (df_daily_return.daily_return + 1).cumprod() - 1

# %%
min_var_cumpod = (portfolio.account_value.pct_change() + 1).cumprod() - 1

# %%
dji_cumpod = (baseline_returns + 1).cumprod() - 1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %formatter:off
# %pip install plotly
# %formatter:on
# Out:
# Requirement already satisfied: plotly in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/zlapik/my-drive-zlapik/0-todo/FinRL-Tutorials/venv3.10/lib/python3.10/site-packages (from plotly) (8.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x=time_ind, y=a2c_cumpod, mode='lines', name='A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x=time_ind, y=dji_cumpod, mode='lines', name='DJIA')
trace2_portfolio = go.Scatter(x=time_ind, y=min_var_cumpod, mode='lines', name='Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
# %matplotlib inline
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)

fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
    #'text': "Cumulative Return using FinRL",
    'y': 0.85,
    'x': 0.5,
    'xanchor': 'center',
    'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
    #    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
    xaxis={'type': 'date',
           'tick0': time_ind[0],
           'tickmode': 'linear',
           'dtick': 86400000.0 * 80}

)
fig.update_xaxes(showline=True, linecolor='black', showgrid=True, gridwidth=1, gridcolor='LightSteelBlue', mirror=True)
fig.update_yaxes(showline=True, linecolor='black', showgrid=True, gridwidth=1, gridcolor='LightSteelBlue', mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
# Out:
# <div>                            <div id="b25a3a82-d284-40a8-b95d-65263337332b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b25a3a82-d284-40a8-b95d-65263337332b")) {                    Plotly.newPlot(                        "b25a3a82-d284-40a8-b95d-65263337332b",                        [{"mode":"lines","name":"A2C (Portfolio Allocation)","x":["2020-07-01","2020-07-02","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-28","2020-09-29","2020-09-30","2020-10-01","2020-10-02","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-12","2020-10-13","2020-10-14","2020-10-15","2020-10-16","2020-10-19","2020-10-20","2020-10-21","2020-10-22","2020-10-23","2020-10-26","2020-10-27","2020-10-28","2020-10-29","2020-10-30","2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-16","2020-11-17","2020-11-18","2020-11-19","2020-11-20","2020-11-23","2020-11-24","2020-11-25","2020-11-27","2020-11-30","2020-12-01","2020-12-02","2020-12-03","2020-12-04","2020-12-07","2020-12-08","2020-12-09","2020-12-10","2020-12-11","2020-12-14","2020-12-15","2020-12-16","2020-12-17","2020-12-18","2020-12-21","2020-12-22","2020-12-23","2020-12-24","2020-12-28","2020-12-29","2020-12-30","2020-12-31","2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-08","2021-02-09","2021-02-10","2021-02-11","2021-02-12","2021-02-16","2021-02-17","2021-02-18","2021-02-19","2021-02-22","2021-02-23","2021-02-24","2021-02-25","2021-02-26","2021-03-01","2021-03-02","2021-03-03","2021-03-04","2021-03-05","2021-03-08","2021-03-09","2021-03-10","2021-03-11","2021-03-12","2021-03-15","2021-03-16","2021-03-17","2021-03-18","2021-03-19","2021-03-22","2021-03-23","2021-03-24","2021-03-25","2021-03-26","2021-03-29","2021-03-30","2021-03-31","2021-04-01","2021-04-05","2021-04-06","2021-04-07","2021-04-08","2021-04-09","2021-04-12","2021-04-13","2021-04-14","2021-04-15","2021-04-16","2021-04-19","2021-04-20","2021-04-21","2021-04-22","2021-04-23","2021-04-26","2021-04-27","2021-04-28","2021-04-29","2021-04-30","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-17","2021-05-18","2021-05-19","2021-05-20","2021-05-21","2021-05-24","2021-05-25","2021-05-26","2021-05-27","2021-05-28","2021-06-01","2021-06-02","2021-06-03","2021-06-04","2021-06-07","2021-06-08","2021-06-09","2021-06-10","2021-06-11","2021-06-14","2021-06-15","2021-06-16","2021-06-17","2021-06-18","2021-06-21","2021-06-22","2021-06-23","2021-06-24","2021-06-25","2021-06-28","2021-06-29","2021-06-30","2021-07-01","2021-07-02","2021-07-06","2021-07-07","2021-07-08","2021-07-09","2021-07-12","2021-07-13","2021-07-14","2021-07-15","2021- ...
